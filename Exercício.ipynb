# %%
import pandas as pd 

areas = pd.read_csv("C:/Users/20221enpro0014/Downloads/areas.csv", sep = ";", decimal = ",")

areas
# Out:
#       Id Bloco  Andar  Final  Sala  Cozinha  Banheiro  Dorm Rachadura  \
# 0      1     A      1      1  27.8      7.9       5.0  11.6   ausente
# 1      2     A      1      2  28.3      7.3       5.4  13.1   ausente
# 2      3     A      1      3  27.1      7.1       5.0  14.9   ausente
# 3      4     A      1      4  26.5      8.4       3.9  12.4  presente
# 4      5     A      2      1  27.7      7.6       4.7  12.1   ausente
# ..   ...   ...    ...    ...   ...      ...       ...   ...       ...
# 147  148     B     18      4  23.5      7.4       4.3  12.2   ausente
# 148  149     B     19      1  24.1      8.3       4.8  12.9   ausente
# 149  150     B     19      2  24.1      8.0       4.5  10.9   ausente
# 150  151     B     19      3  23.0      8.5       4.3  11.7   ausente
# 151  152     B     19      4  22.7      7.8       4.2  15.7   ausente
#
#       Infiltr
# 0     ausente
# 1     ausente
# 2     ausente
# 3    presente
# 4     ausente
# ..        ...
# 147  presente
# ...

# %% [markdown]
# # Questão 1 a)

# %%
len(areas)
# Out:
# 152

# %% [markdown]
# # b)

# %%
tabela_bloco = areas['Bloco'].value_counts()

tabela_bloco
# Out:
# Bloco
# A    76
# B    76
# Name: count, dtype: int64

# %% [markdown]
# # c)

# %%
tabela_andar = areas['Andar'].value_counts()

tabela_andar
# Out:
# Andar
# 1     8
# 11    8
# 18    8
# 17    8
# 16    8
# 15    8
# 14    8
# 13    8
# 12    8
# 10    8
# 2     8
# 9     8
# 8     8
# 7     8
# 6     8
# 5     8
# 4     8
# 3     8
# 19    8
# Name: count, dtype: int64

# %% [markdown]
# # 2)

# %%
area_util = pd.DataFrame(areas)

area_util["Área útil"] = area_util ["Sala"] + area_util ["Cozinha"] + area_util ["Banheiro"] + area_util ["Dorm"]

area_util
# Out:
#       Id Bloco  Andar  Final  Sala  Cozinha  Banheiro  Dorm Rachadura  \
# 0      1     A      1      1  27.8      7.9       5.0  11.6   ausente
# 1      2     A      1      2  28.3      7.3       5.4  13.1   ausente
# 2      3     A      1      3  27.1      7.1       5.0  14.9   ausente
# 3      4     A      1      4  26.5      8.4       3.9  12.4  presente
# 4      5     A      2      1  27.7      7.6       4.7  12.1   ausente
# ..   ...   ...    ...    ...   ...      ...       ...   ...       ...
# 147  148     B     18      4  23.5      7.4       4.3  12.2   ausente
# 148  149     B     19      1  24.1      8.3       4.8  12.9   ausente
# 149  150     B     19      2  24.1      8.0       4.5  10.9   ausente
# 150  151     B     19      3  23.0      8.5       4.3  11.7   ausente
# 151  152     B     19      4  22.7      7.8       4.2  15.7   ausente
#
#       Infiltr  Área útil
# 0     ausente       52.3
# 1     ausente       54.1
# 2     ausente       54.1
# ...

# %% [markdown]
# # 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(areas['Sala'], bins = 8, edgecolor = "black")
plt.title("Áreas das salas")
plt.xlabel("Apt")
plt.ylabel("Área")
# Out:
# Text(0, 0.5, 'Área')
